# %% [markdown]
# # <center> Lab 2 Problems
# ## <center> Surfaces of Revolution and Length
# Add all needed libraries.

# %% [markdown]
# ### Problem 1
#
#
# **a.** Write a `def` function that approximates volume of surface of revolution with respect to $y$-axis using shell method. (Hint: you can modify WasherVol function from Examples file)

# %% [markdown]
# **b.** A pond is approximately circular, with a diameter of 400 feet. Starting at the center, the depth of the
# water is measured every 25 feet and recorded in the table below:
#
# $$
# \begin{aligned}
# &\begin{array}{|c|c|c|c|c|c|c|c|c|c|}
# \hline \hline
# r & 0 & 25 & 50 & 75 & 100 & 125 & 150 & 175 & 200\\
# \hline
# Depth & 20 & 19 & 19 & 17 & 15 & 14 & 10 & 6 & 0\\
# \hline
# \end{array}
# \end{aligned}
# $$
#
# Find the model of this data in the form of quadratic polynomial. Plot the graph and data on the same
# graph.

# %% [markdown]
# **c.** Use def function from part **a** to find the approximate volume using $n=16$ and $n=100$

# %% [markdown]
# **d.** Find the volume of the pond by using integration. (Hint: you will have to multiply your model polynomial by $2\pi x$ in order to do shell method. To do that, you can create another polynomial that equal to $2\pi x$ and then multiply it by your model polynomial.)

# %% [markdown]
# **e.** Using the formula $Error=\frac{|Approximation-Actual|}{Actual} \cdot 100\%$, compute the error of approximation with $n=16$ and $n=100$

# %% [markdown]
# ### Problem 2
#
# Property bound by two perpendicular roads and a river. Distances from the river to one of the roads are
# given in the picture below. Distances are given in feet.
#
# ![lab2pr2.png](attachment:2b08cca4-e083-4390-a249-e93537bd03a9.png)
#
# **a.** Find the model of this data in the form of fourth degree polynomial. Plot the graph and data on the
# same graph.

# %% [markdown]
# **b.** Find approximate length of the river adjacent to property

# %% [markdown]
# **Answer:**

# %% [markdown]
# **c.** What is the area of the property?

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Problem 3
#
# A lampshade is constructed by rotating $y = \frac{1}{x^2}$ around the $x$-axis from $x = 1$ foot to $x = 2$ feet.
#
# **a.** Modify `Washer3D` function from examples file to draw one surface of revolution around x-axis (i.e. Disk Method)

# %% [markdown]
# **b.** Draw 3d picture of the lampshade using the function from part **a**.

# %% [markdown]
# **c.** Suppose you have to pay 2 dollars per square foot of material. How much do you have to pay for the
# material for this lampshade?

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Problem 4 (Homer's Dream)

# %% [markdown]
# You found a perfect donut! Its cross-section is a perfect circle of radius 0.7 inches. Its inner hole has
# radius 0.5 inches.
#
# **a.** What is the equation of a circle such that if we rotate it around x-axis, we will get the shape of our
# donut? [There is more than 1 right answer]

# %% [markdown]
# **Answer:**

# %% [markdown]
# **b.** Create two functions: one representing upper half circle and another representing lower half-circle of cross-section. Plot
# both on the same graph to confirm that you have the right functions.
#
# Note: it will look better if in `figsize` you use the same lenght and width. And restrict `xlim` and `ylim` to the same values (I would recommend from -2 to 2)

# %% [markdown]
# **c.** Plot your donut. You can reuse `Washer3D` with few little changes: make all axis go from -2 to 2; and also change view to `ax.view_init(20,40,0)`

# %% [markdown]
# **d.** What is the volume of your donut?

# %% [markdown]
# **Answer:**

# %% [markdown]
# **e.** Suppose you cover half of the donut with chocolate. How much of a surface area of a donut is covered by
# chocolate?
#
# ***NOTE: The integrant will be too complicated for SymPy to solve in any resonable amount of time if at all. Therefore, you should estimate it using Riemann Sums. Take at least $n=100$.***

# %% [markdown]
# **Answer:**

# %% [markdown]
# ![image.png](attachment:image.png)
