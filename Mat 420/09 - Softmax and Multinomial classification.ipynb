# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import torch
import torch.nn as nn
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Softmax
#
# When we did a two class classification with logistic regression, we used a sigmoid function as our activatin function to produce probabilities for each class. However, sigmoid will not work well if we have multiple classes. Sigmoid will produce probabilities of individual classes and it assumes the input can belong to multiple classes and so the total will not add up to one usually. Instead we can use a generalized version of this function called Softmax. For $K$ classes softmax looks like this:
#
# $$S({\bf x})_j=\frac{e^{x_j}}{\sum_i^K e^{x_i}}$$
#
# The output is a probability vector. The higher the value of $x_j$ is, the higher the corresponding probability $S({\bf x})_j$ is.
#
# Link to play around in Desmos: https://www.desmos.com/calculator/drqqhtb037
#
# So, to classify input ${\bf x}$, we can apply softmax followed by $argmax$ function which is a function that picks the class with highest probability. Let's look at the example with 4 classes.

# %%
x=np.array([0.3, -3.4, 1.6, 0])

def Softmax(x):
    return np.exp(x)/np.exp(x).sum()

Softmax(x)
# Out:
# array([0.18399811, 0.00454908, 0.67514365, 0.13630915])

# %%
np.argmax(Softmax(x))
# Out:
# 2

# %% [markdown]
# As you can see, we get the class 2 (1.6 is the largest number).
#
# The result is always a class whose value is largest, so it might be tempting to forget softmax and apply argmax right away. However, gradients of argmax are zero, so it will not work with backpropagation. In other words, argmax is a good function as a threshold function, but not as a activation function.
#
# One more thing to note. For binary classification, weights for our linear model depend only on number features. However, for multinomial case, they depend on number of features and number of classes. To see this consider what we are looking for. We want to get probability of getting one of the classes given some features $x^{(i)}$  (i.e. $P(y=k \:|\: x^{(i)})$). In other words we want a vector:
#
# $$\begin{bmatrix}P(y=1 \:|\: {\bf x^{(i)})} \\ P(y=2 \:|\: {\bf x^{(i)})}\\ \cdots \\ P(y=c \:|\: {\bf x^{(i)})} \end{bmatrix}.$$
#
# For each of those probabilities we will use linear classifier as in logistic regression, but each of those probabilities may have different weights and biases:
#
# $$\begin{bmatrix}{\bf x^{(i)} \cdot w_1} +b_1\\ {\bf x^{(i)} \cdot w_2}+b_2\\ \cdots \\ {\bf x^{(i)} \cdot w_c} +b_c \end{bmatrix} = W {\bf x^{(i)}} +{\bf b}$$
#
# So, we no longer have a weight vector, but a $f \times c$ weight matrix $W$. Finally, the result so far is not a probability vector and so we use Softmax function to make it into probability vector.
#
#
# Our forward pass then will compute ${ \bf a}=S(W {\bf x^{(i)}} +{\bf b})$ or if we have usual array of data $X$, we can rewrite this as $S(XW^T +{\bf b})$

# %% [markdown]
# ### Cross Entropy Loss Function
#
# Another thing we need to generalize is a loss function. For binary classification logistic regression, we used negative log likelihood loss function (also known as binary cross entropy function):
# $$LogL_{{\bf w}, b}=-\frac{1}{N}\sum_{i=1}^{N}y^{(i)} \ln(\hat{y}^{(i)})+(1-y^{(i)})\ln(1-\hat{y}^{(i)})$$
#
# This assumes binary classification since we use probabilities $y^{(i)}$ and $1-y^{(i)}$. We can sightly rewrite this by considering $y$ and $\hat{y}$ as vectors of true class probabilities and predicted class probabilities:
#
# $$LogL=- \frac{1}{N}\sum_{i=1}^{N}\left(y^{(i)}_1 \cdot \ln(\hat{y}^{(i)}_1)+ y_2^{(i)} \cdot \ln(\hat{y}^{(i)}_2) \right)= -\frac{1}{N} \sum_{i=1}^{N}\sum_{c=1}^2 y^{(i)}_c \cdot \ln(\hat{y}^{(i)}_c)=-\frac{1}{N} \sum_{i=1}^N {\bf y}^{(i)} \cdot \ln(\hat{\bf y}^{(i)}) $$
#
# Note that ${\bf y}^{(i)}$ is just a vector full of zeros and and single 1.
# We generalize this to Cross Entropy Loss Function for $K$ classes:
#
# $$L=-\frac{1}{N} \sum_{i=1}^N  {\bf y}^{(i)} \cdot \ln(\hat{\bf y}^{(i)})=-\frac{1}{N} \sum_{i=1}^N  {\bf y}^{(i)} \cdot \ln(a^{(i)})$$
#
# Note: since our target is a certain number representing a class. Each ${\bf y}^{(i)}$ has to be one hot encoded.
#
# The gradient (or more precisely Jacobian, since W is a matrix) is a bit tricker to compute. Consider the following diagram showing 3 features and 2 classes:
#
# ![Crossetropypropagation.png](attachment:7e1b5573-c074-46cc-a1d5-e67e7be2131a.png)

# %% [markdown]
# In the example above, let's pick one of the entries of the Jacobian and compute it:
# $$\begin{equation}
# \begin{aligned}
# \frac{\partial L}{\partial w_{3,2}} & = \frac{\partial L}{\partial a_1}\cdot\frac{\partial a_1}{\partial z_2}\cdot\frac{\partial z_2}{\partial w_{2,3}} + \frac{\partial L}{\partial a_2}\cdot\frac{\partial a_2}{\partial z_2}\cdot\frac{\partial z_2}{\partial w_{2,3}} \\
# & = -\frac{y_1}{a_1} \cdot (-a_1a_2) \cdot x_3 + -\frac{y_2}{a_2}\cdot (-a_2(1-a_2)) \cdot x_3 \\
# & = - (y_2 - a_2 )x_3
# \end{aligned}
# \end{equation}$$
#
# Putting back the $1/N$ and rewriting it as matrix multiplication we get the full Jacobian:
#
# $$ \nabla_W L = -\left(\frac{1}{N} (Y-A)^TX\right)^T$$
#
# Note that $Y$ and $A$ are $n \times c$ matrices, each row of which is a target probability vector for each data point.
#
# And for bias term it is quite similar:
# $$\frac{\partial L}{\partial {\bf b}}=-\frac{1}{N}\sum_{i=1}^{N}(y-a)$$
#
# Compare this to what we had in the binary case. You should see it is quite similar, though calculations here are much harder. For more details on calculations, you can check the following video: https://www.youtube.com/watch?v=aeM-fmcdkXU

# %% [markdown]
# ### Examples
# Let's try it on Iris data set.
#
# First we upload the set, scale it and look at pairwise plot

# %%
# Helper function to plot a decision boundary.
def plot_decision_boundary(X, y, model, resolution=0.02):
    colors = ['red', 'blue', 'lightgreen', 'gray', 'cyan']
    cmap = ListedColormap(colors[:len(np.unique(y))])
    markers = ('s', 'x', 'o', '^', 'v')      
    
    # Set min and max values and give it some padding
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1

    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, resolution), np.arange(y_min, y_max, resolution))
    # Predict the function value for the whole grid
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())


    for idx, cl in enumerate(np.unique(y)): 
        plt.scatter(X[y==cl, 0], X[y==cl, 1],  color=cmap(idx),edgecolors='k',marker=markers[idx],label=cl)

# %%
dataset=datasets.load_iris()
X = dataset.data
y = dataset.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
sc=StandardScaler()

X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
df = pd.DataFrame(data=X_train, columns=dataset.feature_names)
df['type'] = pd.DataFrame(data=y_train)
label_dict = {0:'Setosa',1:'Versicolour', 2:'Virginica'}
df['type']=df.type.map(label_dict)
sns.pairplot(df, hue="type")
plt.show()

# %% [markdown]
# Let's consider petal lenght and petal width and apply multinomial logistic regression

# %%
X2_train=X_train[:,[2,3]]
y2_train=y_train
X2_test=X_test[:,[2,3]]
y2_test=y_test

# %%
n_samples, n_features = X2_train.shape

lr=0.01
n_epoch=5000

# %%
class MultiClassLogisticRegression:
    
    def __init__(self, n_epoch = 10000, lr=0.01, thres=0.001):
        self.n_epoch = n_epoch
        self.thres = thres
        self.lr=lr
        self.weights=None
        self.bias=None

    def onehot(self, y):
        classes = np.unique(y)
        y = np.eye(len(classes))[y]
        return y

    def softmax(self, z):
        return np.exp(z) / np.sum(np.exp(z), axis=1).reshape(-1,1)

    def cross_entropy(self, a, y):
        return -1 * np.mean(y * np.log(a))

    def forward(self, X):
        z=np.dot(X, self.weights)+self.bias
        a=self.softmax(z)
        return z,a
    
    def fit(self, X, y): 
        n_class=len(np.unique(y))
        n_samples, n_feat = X.shape
        self.weights= np.zeros(( n_feat, n_class))
        self.bias=np.zeros(n_class)

        for i in range(self.n_epoch):
            y_hot=self.onehot(y)

            z, a = self.forward(X)

            dw=-np.dot((y_hot-a).T, X).T/X.shape[0]
            db=-(y_hot-a).mean(axis=0)
            
            if np.abs(dw).max() < self.thres: break
                
            self.weights = self.weights - self.lr*dw
            self.bias = self.bias - self.lr*db
            
            loss=np.mean(self.cross_entropy(a,y_hot))

            if (i+1)%1000 == 0:
                print(f'Epoch = {(i+1)}:, Loss: {loss:.03f}')

    
    def predict(self, X):

        _, a=self.forward(X)
        return np.argmax(a, axis=1)
      
    def score(self, X, y):
        return np.mean(self.predict(X) == y)

# %%
model= MultiClassLogisticRegression(n_epoch,lr)

# %%
model.fit(X2_train, y2_train)
# Out:
# Epoch = 1000:, Loss: 0.127
# Epoch = 2000:, Loss: 0.097
# Epoch = 3000:, Loss: 0.081
# Epoch = 4000:, Loss: 0.072
# Epoch = 5000:, Loss: 0.065

# %%
print('Weights: ' ,model.weights)
print('bias: ',model.bias)
# Out:
# Weights:  [[-2.26774128  0.34318185  1.92455944]
#  [-2.00455321 -0.37846976  2.38302297]]
# bias:  [-0.67332438  1.58872121 -0.91539683]

# %%
plot_decision_boundary(X2_train, y2_train, model)
plt.legend(loc='upper left')
plt.title("Train Data")
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.tight_layout()
plt.show()
print("Accuracy = ", model.score(X2_train, y2_train))
# Out:
# Accuracy =  0.9583333333333334

# %%
y_train_pred=model.predict(X2_train)
confusion_matrix(y2_train,y_train_pred)
# Out:
# array([[40,  0,  0],
#        [ 0, 37,  2],
#        [ 0,  3, 38]], dtype=int64)

# %%
plot_decision_boundary(X2_test, y2_test, model)
plt.title("Test Data")
plt.legend(loc='upper left')
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.tight_layout()
plt.show()
print("Accuracy = ", model.score(X2_test, y2_test))
# Out:
# Accuracy =  0.9666666666666667

# %%
y_test_pred=model.predict(X2_test)
confusion_matrix(y2_test,y_test_pred)
# Out:
# array([[10,  0,  0],
#        [ 0, 10,  1],
#        [ 0,  0,  9]], dtype=int64)

# %% [markdown]
# Here is a fast way using Sklearn:

# %%
model = LogisticRegression( solver='sag',multi_class='multinomial', max_iter=n_epoch)
model.fit(X2_train, y2_train)
plot_decision_boundary(X2_test,y2_test,model)
plt.title("Test Data")
plt.legend(loc='upper left')
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.tight_layout()
plt.show()
print("Accuracy = ", model.score(X2_test, y2_test))
# Out:
# Accuracy =  0.9666666666666667

# %% [markdown]
# As you can see, it differs a bit. SKlearn's Logistic Regression doesn't support GD or SGD. In the above example we used `solver='sag'`, which stands for "Stochastic Average Gradient". There are many other optimizers that can be used.

# %% [markdown]
# We can also perform logistic regression using different approaches. We just did a multinomial approach with gradient descent. Another common way is to use OVR (one versus the rest). In this case, we go through loop each time we do a binary logistic regression using one class and the rest as another class. So, in essence we have multiple binary models. Given a data point we look at the probabilties in each model of data point belonging to a specific class. Here what it will look like using SKlearn:

# %%
model = LogisticRegression( penalty='l2', solver='sag',multi_class='ovr', max_iter=n_epoch)
model.fit(X2_train, y2_train)
plot_decision_boundary(X2_train,y2_train,model)
plt.title("Train Data")
plt.legend(loc='upper left')
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.tight_layout()
plt.show()
print("Accuracy = ", model.score(X2_train, y2_train))
# Out:
# Accuracy =  0.95

# %%
plot_decision_boundary(X2_test,y2_test,model)
plt.title("Test Data")
plt.legend(loc='upper left')
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.tight_layout()
plt.show()
print("Accuracy = ", model.score(X2_test, y2_test))
# Out:
# Accuracy =  0.9333333333333333

# %% [markdown]
# There is also OVO (one vs one). In this case we would do multiple binary logistic regression models each time comparing only two classes (e.g. green vs red, blue vs red, green vs blue).
#
# ### PyTorch Example

# %%
X3_train=torch.tensor(X2_train, dtype=torch.float)
y3_train=torch.tensor(y2_train, dtype=torch.int)
X3_test=torch.tensor(X2_test, dtype=torch.float)
y3_test=torch.tensor(y2_test, dtype=torch.int)

n_samples, n_features = X3_train.shape


lr=0.01
n_epoch=5000
thres=0.001

# %%
class MultiClassLogisticRegression(torch.nn.Module):

    def __init__(self, num_features, num_classes):
        super(MultiClassLogisticRegression, self).__init__()
        self.linear = torch.nn.Linear(num_features, num_classes)
        # initialize weights to zeros here,
        # since we used zero weights in the
        # manual approach
        
        self.linear.weight.detach().zero_()
        self.linear.bias.detach().zero_()
        # Note: the trailing underscore
        # means "in-place operation" in the context
        # of PyTorch
        
    def forward(self, x):
        logits = self.linear(x)
        probas = nn.Softmax()(logits)
        return logits, probas

model2 = MultiClassLogisticRegression(num_features=n_features, num_classes=3)
optimizer = torch.optim.SGD(model2.parameters(), lr=lr)
lossfunc=nn.CrossEntropyLoss()

# %%
def comp_accuracy(true_labels, pred_labels):
    accuracy = torch.sum(true_labels.view(-1).float() == 
                         pred_labels.float()).item() / true_labels.size(0)
    return accuracy



train_loss=[]
test_loss=[]
Time=n_epoch

for epoch in range(n_epoch):
    
    #### Compute outputs ####
    logits, probas = model2(X3_train)
    
    #### Compute gradients ####
    loss = lossfunc(logits, y3_train.long())    #BCE applies softmax already
    optimizer.zero_grad()
    loss.backward()
    train_loss.append(loss.item())
    #### Update weights ####  
    optimizer.step()
    


    model2.eval()

    
    with torch.inference_mode(): 

        #### Logging ####      
        logits, probas = model2(X3_train)
        acc = comp_accuracy(y3_train, torch.argmax(probas, dim=1))

        if (epoch+1)%500 ==0:
            print('Epoch: %03d' % (epoch + 1), end="")
            print(' | Train ACC: %.3f' % acc, end="")
            print(' | Cost: %.3f' % lossfunc(logits, y3_train.long()))
        y_test_pred,_=model2(X3_test)
        lost_test=lossfunc(y_test_pred, y3_test.long())
        test_loss.append(lost_test)
        if np.abs(model2.linear.weight.grad.max()) < thres: 
            Time=epoch+1
            break
        
print('\nModel parameters:')
print('  Weights: %s' % model2.linear.weight)
print('  Bias: %s' % model2.linear.bias)
# Out:
# Epoch: 500 | Train ACC: 0.808 | Cost: 0.478
# Epoch: 1000 | Train ACC: 0.942 | Cost: 0.381
# Epoch: 1500 | Train ACC: 0.958 | Cost: 0.327
# Epoch: 2000 | Train ACC: 0.967 | Cost: 0.290
# Epoch: 2500 | Train ACC: 0.967 | Cost: 0.264
# Epoch: 3000 | Train ACC: 0.967 | Cost: 0.244
# Epoch: 3500 | Train ACC: 0.958 | Cost: 0.228
# Epoch: 4000 | Train ACC: 0.958 | Cost: 0.215
# Epoch: 4500 | Train ACC: 0.958 | Cost: 0.204
# Epoch: 5000 | Train ACC: 0.958 | Cost: 0.195
#
# Model parameters:
#   Weights: Parameter containing:
# tensor([[-2.2677, -2.0046],
#         [ 0.3432, -0.3785],
#         [ 1.9246,  2.3830]], requires_grad=True)
#   Bias: Parameter containing:
# tensor([-0.6733,  1.5887, -0.9154], requires_grad=True)

# %%
fig=plt.figure()
xv=np.arange(1,Time,1)
plt.plot(xv,train_loss[1:], 'r', label="Train Loss")
plt.plot(xv,test_loss[:-1], 'b', label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()

# %%
def plot_decision_boundary_torch(X, y, classifier, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    tensor = torch.tensor(np.array([xx1.ravel(), xx2.ravel()]).T).float()
    _, probas = classifier.forward(tensor)
    Z = np.argmax(probas.detach().numpy(), axis=1)

    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class samples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, color=cmap(idx),
                    edgecolor='black',
                    marker=markers[idx], 
                    label=cl)

# %%
plot_decision_boundary_torch(X3_train, y3_train, classifier=model2)
plt.title("Train Data")
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
plot_decision_boundary_torch(X3_test, y3_test, classifier=model2)
plt.title("Test Data")
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
